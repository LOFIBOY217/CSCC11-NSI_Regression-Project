# %%
################### standard ###################
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch

################### allow import from src ###################
import sys, os
sys.path.append(os.path.abspath(".."))

################### pipeline step ###################
import src.data_prep as data
import src.models.LSTM_model as lstm
import src.config.feature_def as feature_def
import src.models.utils as utils

# %%
monthly = data.prepare_monthly_dataset("../data/Major_Crime_Indicators_Open_Data.csv")

################ define features ################
feature_cols = feature_def.FEATURE_NSI_3M
target_col = feature_def.TARGET_COL

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using:", device)

model, y_test, y_pred, metrics, scaler = lstm.train_lstm_pipeline(
    df=monthly,
    feature_cols=feature_cols,
    target_col=target_col,
    seq_length=12,
    hidden_size=256,
    num_layers=2,
    batch_size=32,
    epochs=50,
    device=device,
    create_sequences_fn=lstm.create_sequences_per_neighborhood
)

print(metrics)
# Out:
# Using: cpu
# [1/50] Loss = 0.0112
# [2/50] Loss = 0.0029
# [3/50] Loss = 0.0029
# [4/50] Loss = 0.0030
# [5/50] Loss = 0.0028
# [6/50] Loss = 0.0027
# [7/50] Loss = 0.0027
# [8/50] Loss = 0.0026
# [9/50] Loss = 0.0026
# [10/50] Loss = 0.0026
# [11/50] Loss = 0.0026
# [12/50] Loss = 0.0026
# [13/50] Loss = 0.0026
# [14/50] Loss = 0.0026
# [15/50] Loss = 0.0026
# [16/50] Loss = 0.0026
# [17/50] Loss = 0.0026
# [18/50] Loss = 0.0026
# [19/50] Loss = 0.0026
# [20/50] Loss = 0.0025
# [21/50] Loss = 0.0025
# [22/50] Loss = 0.0025
# [23/50] Loss = 0.0025
# [24/50] Loss = 0.0025
# [25/50] Loss = 0.0025
# [26/50] Loss = 0.0025
# [27/50] Loss = 0.0025
# [28/50] Loss = 0.0025
# [29/50] Loss = 0.0025
# [30/50] Loss = 0.0025
# [31/50] Loss = 0.0025
# [32/50] Loss = 0.0025
# [33/50] Loss = 0.0025
# [34/50] Loss = 0.0025
# [35/50] Loss = 0.0025
# [36/50] Loss = 0.0025
# [37/50] Loss = 0.0025
# [38/50] Loss = 0.0024
# [39/50] Loss = 0.0024
# [40/50] Loss = 0.0024
# [41/50] Loss = 0.0024
# [42/50] Loss = 0.0024
# [43/50] Loss = 0.0024
# [44/50] Loss = 0.0024
# [45/50] Loss = 0.0024
# [46/50] Loss = 0.0024
# [47/50] Loss = 0.0024
# [48/50] Loss = 0.0024
# [49/50] Loss = 0.0024
# [50/50] Loss = 0.0024
# {'R2': 0.8304652571678162, 'MAE': 0.04144646227359772, 'MSE': 0.0035484503023326397, 'RMSE': 0.059568870245562316}
