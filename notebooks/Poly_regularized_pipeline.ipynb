# %%
################### standard ###################
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

################### allow import from src ###################
import sys, os
sys.path.append(os.path.abspath(".."))

################### pipeline step ###################
import src.data_prep as data
import src.models.poly_reg_regularized as poly_reg_regularized
import src.config.feature_def as feature_def
import src.models.utils as utils

# %%
monthly = data.prepare_monthly_dataset("../data/Major_Crime_Indicators_Open_Data.csv")

feature_cols = feature_def.FEATURE_NSI_3M
target_col = feature_def.TARGET_COL

# %%
results, best = poly_reg_regularized.poly_reg_hparam_search(monthly, feature_cols, "NSI")
best
# Out:
# /opt/anaconda3/envs/cscc11/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.858e-02, tolerance: 2.425e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/cscc11/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.448e+00, tolerance: 2.425e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/cscc11/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.571e+00, tolerance: 2.425e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/cscc11/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.016e+01, tolerance: 2.425e-02
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/envs/cscc11/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.307e-01, tolerance: 2.425e-02
#   model = cd_fast.enet_coordinate_descent(
# {'degree': 1,
#  'alpha': 0.01,
#  'reg_type': 'ridge',
#  'R2': 0.814325402118658,
#  'RMSE': 0.05575677268994427}
